# %%
from mysql.connector import pooling, Error

# Database configuration
dbconfig = {
    "host": "localhost",
    "user": "root",
    "password": "Geetesh@123",
    "database": "little_lemon"
}

try:
    pool_b = pooling.MySQLConnectionPool(
        pool_name="pool_b",
        pool_size=2,
        **dbconfig
    )

    print("Connection pool 'pool_b' created successfully!")

except Error as e:
    print("Error while creating connection pool:", e)
# Out:
# Connection pool 'pool_b' created successfully!

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\geete\AppData\Local\Programs\Python\Python310\python.exe

# %%
# !python --version
# Out:
# Python 3.10.11

# %%
import sys
# !{sys.executable} -m pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-26.7.0-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Downloading mysql_connector_python-26.7.0-cp310-cp310-win_amd64.whl (17.7 MB)
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/17.7 MB 1.3 MB/s eta 0:00:14
#    - -------------------------------------- 0.8/17.7 MB 1.0 MB/s eta 0:00:17
#    -- ------------------------------------- 1.0/17.7 MB 1.1 MB/s eta 0:00:15
#    --- ------------------------------------ 1.6/17.7 MB 1.3 MB/s eta 0:00:13
#    ---- ----------------------------------- 1.8/17.7 MB 1.4 MB/s eta 0:00:12
#    ---- ----------------------------------- 2.1/17.7 MB 1.5 MB/s eta 0:00:11
#    ----- ---------------------------------- 2.6/17.7 MB 1.5 MB/s eta 0:00:10
#    ------- -------------------------------- 3.1/17.7 MB 1.6 MB/s eta 0:00:10
#    ------- -------------------------------- 3.4/17.7 MB 1.6 MB/s eta 0:00:09
#    -------- ------------------------------- 3.7/17.7 MB 1.6 MB/s eta 0:00:09
#    -------- ------------------------------- 3.9/17.7 MB 1.6 MB/s eta 0:00:09
#    ---------- ----------------------------- 4.5/17.7 MB 1.6 MB/s eta 0:00:09
#    ----------- ---------------------------- 5.0/17.7 MB 1.7 MB/s eta 0:00:08
#    ----------- ---------------------------- 5.2/17.7 MB 1.6 MB/s eta 0:00:08
#    ------------ --------------------------- 5.5/17.7 MB 1.6 MB/s eta 0:00:08
#    ------------- -------------------------- 6.0/17.7 MB 1.7 MB/s eta 0:00:08
#    -------------- ------------------------- 6.6/17.7 MB 1.7 MB/s eta 0:00:07
#    ---------------- ----------------------- 7.3/17.7 MB 1.8 MB/s eta 0:00:06
#    ----------------- ---------------------- 7.9/17.7 MB 1.9 MB/s eta 0:00:06
#    ------------------ --------------------- 8.4/17.7 MB 1.9 MB/s eta 0:00:05
#    -------------------- ------------------- 9.2/17.7 MB 2.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 10.0/17.7 MB 2.1 MB/s eta 0:00:04
#    ------------------------ --------------- 10.7/17.7 MB 2.1 MB/s eta 0:00:04
#    -------------------------- ------------- 11.5/17.7 MB 2.2 MB/s eta 0:00:03
#    --------------------------- ------------ 12.1/17.7 MB 2.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 12.8/17.7 MB 2.3 MB/s eta 0:00:03
#    ------------------------------ --------- 13.6/17.7 MB 2.3 MB/s eta 0:00:02
#    -------------------------------- ------- 14.4/17.7 MB 2.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 15.2/17.7 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------ --- 16.0/17.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 16.3/17.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 16.5/17.7 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 16.8/17.7 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 16.8/17.7 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  17.6/17.7 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 17.7/17.7 MB 2.3 MB/s  0:00:07
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-26.7.0
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\geete\appdata\local\programs\python\python310\lib\site-packages (26.7.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
